# %%
import simulacion

# %%
mientorno = simulacion.Entorno()
mientorno.crear_nervio

# %% [markdown]
# Ir ejecutando linea por linea, paso por paso

# %%
a = simulacion.Entorno(nombre='Experimento_01')
a.crear_nervio(diametro = 1500,num_fibras=250,metodo_poblacion = 'uniforme_con_superposicion',diametro_fibra=4.5,distancia_nodos=2000,longitud=50000,porcentaje_cobertura=100,var_diametro=1.5,variacion_nodos = 0)
a.crear_electrodo(tipo='punto',pos_x = 0,pos_y = -750,pos_z = 10000,zona_influencia=4000,grosor=0,funcion = simulacion.funcion_gaussiana)
a.crear_electrodo(tipo='poligono',lista_coordenadas = [(-100,-750),(100,-750),(100,-800),(-100,-800)],pos_z = 20000,zona_influencia=4000,grosor=0,funcion = simulacion.funcion_gaussiana)
a.crear_estimulo(tipo_estimulo='potencial_de_accion',frec_muestreo=100000,tiempo_estimulo=0.003,tiempo_inicio = 0.001,frec_corte = 1000,orden_filtro = 2)

# %%
a.dibujar_entorno()
