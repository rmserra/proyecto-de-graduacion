# %%
import simulacion

# %%
experimento_02 = simulacion.Entorno(nombre = 'Mi_Experimento_02')

# %%
experimento_02.crear_nervio(diametro = 1265,
				                    longitud = 50000,
				                    num_fibras = 5207,
				                    diametro_fibra = 4.5,
				                    var_diametro = 1.5,
				                    distancia_nodos = 2000,
									conductividad_transversal=None,
				                    porcentaje_cobertura=100,
				                    metodo_poblacion='uniforme_con_superposicion',
					                  semilla=None,
				                    alfa=7.6,
				                    velocidad=None,
				                    variacion_nodos=500,
				                    distribucion_variacion='uniforme',
				                    desplazamiento=500)

# %%
# Primer electrodo
experimento_02.crear_electrodo(tipo = 'circulo',
															 pos_x = 0,
															 pos_y = -800,
															 pos_z = 10000,
                											radio = 50,
															 zona_influencia = 10000,
															 grosor=500,
															 funcion=simulacion.funcion_trapecio)

# %%
# Segundo electrodo
experimento_02.crear_electrodo(tipo = 'poligono',
								pos_z = 20000,
        						lista_coordenadas = [(-100,-800),(-100,-750),(100,-750),(100,-800)],
								zona_influencia = 10000,
								 grosor=500,
								 funcion=simulacion.funcion_trapecio)

# %%
experimento_02.crear_estimulo(tipo_estimulo = 'potencial_de_accion',
															frec_muestreo = 100000,
															tiempo_estimulo = 0.003,
															tiempo_inicio = 0.001,
															frec_corte = 1000,
															orden_filtro = 2)

# %%
experimento_02.cap()

# %%
experimento_02.cap_diferencial(posicion_1 = 0, posicion_2 = 1)

# %%
experimento_02.graficas(guardar=True)

# %%
experimento_02 = simulacion.Entorno(nombre = 'Mi_Experimento_02')

experimento_02.crear_nervio(diametro = 1265,
				                    longitud = 50000,
				                    num_fibras = 5207,
				                    diametro_fibra = 4.5,
				                    var_diametro = 1.5,
				                    distancia_nodos = 2000,
									conductividad_transversal=None,
				                    porcentaje_cobertura=100,
				                    metodo_poblacion='uniforme_con_superposicion',
					                  semilla=None,
				                    alfa=7.6,
				                    velocidad=None,
				                    variacion_nodos=500,
				                    distribucion_variacion='uniforme',
				                    desplazamiento=500)


# Primer electrodo
experimento_02.crear_electrodo(tipo = 'circulo',
															 pos_x = 0,
															 pos_y = -682.5,
															 pos_z = 10000,
                											radio = 50,
															 zona_influencia = 10000,
															 grosor=1000,
															 funcion=simulacion.funcion_trapecio)

# Segundo electrodo
experimento_02.crear_electrodo(tipo = 'poligono',
								pos_z = 20000,
        						lista_coordenadas = [(-100,-685),(-100,-635),(100,-635),(100,-685)],
								zona_influencia = 10000,
								 grosor=1000,
								 funcion=simulacion.funcion_trapecio)

experimento_02.crear_estimulo(tipo_estimulo = 'potencial_de_accion',
															frec_muestreo = 100000,
															tiempo_estimulo = 0.003,
															tiempo_inicio = 0.001,
															frec_corte = 1000,
															orden_filtro = 2)

experimento_02.cap()
experimento_02.cap_diferencial(posicion_1 = 0, posicion_2 = 1)
experimento_02.graficas()
experimento_02.dibujar_entorno()

# %%
experimento_02 = simulacion.Entorno(nombre = 'Mi_Experimento_02')

experimento_02.crear_nervio(diametro = 1500,
				                    longitud = 50000,
				                    num_fibras = 4000,
				                    diametro_fibra = 4.5,
				                    var_diametro = 1.5,
				                    distancia_nodos = 2000,
									conductividad_transversal=None,
				                    porcentaje_cobertura=100,
				                    metodo_poblacion='uniforme_con_superposicion',
					                semilla=None,
				                    alfa=7.6,
				                    velocidad=None,
				                    variacion_nodos=0,
				                    distribucion_variacion='uniforme',
				                    desplazamiento=0)


# Primer electrodo
experimento_02.crear_electrodo(tipo = 'punto',
								pos_x = 0,
								pos_y = -750,
								pos_z = 10000,
								zona_influencia = 10000,
								grosor=0,
								funcion=simulacion.funcion_trapecio)

# Segundo electrodo
experimento_02.crear_electrodo(tipo = 'punto',
                               pos_x = 0,
                               pos_y = -750,
							   pos_z = 20000,
							   zona_influencia = 10000,
							   grosor=0,
							   funcion=simulacion.funcion_trapecio)

experimento_02.crear_estimulo(tipo_estimulo = 'potencial_de_accion',
															frec_muestreo = 100000,
															tiempo_estimulo = 0.003,
															tiempo_inicio = 0.001,
															frec_corte = 1000,
															orden_filtro = 2)

experimento_02.cap()
experimento_02.cap_diferencial(posicion_1 = 0, posicion_2 = 1)
experimento_02.graficas()
experimento_02.dibujar_entorno()

# %%
experimento_02.archivo_matlab(nombre = "exp_2.mat")
